# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %%
## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 8)]          0           []
#
#  dense (Dense)                  (None, 128)          1152        ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 128)          16512       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 64)           8256        ['dense_1[0][0]']
#
#  y1_output (Dense)              (None, 1)            129         ['dense_1[0][0]']
#
#  y2_output (Dense)              (None, 1)            65          ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 [==============================] - 1s 7ms/step - loss: 261.2294 - y1_output_loss: 124.6668 - y2_output_loss: 136.5627 - y1_output_root_mean_squared_error: 11.1654 - y2_output_root_mean_squared_error: 11.6860 - val_loss: 33.8129 - val_y1_output_loss: 15.2648 - val_y2_output_loss: 18.5481 - val_y1_output_root_mean_squared_error: 3.9070 - val_y2_output_root_mean_squared_error: 4.3068
# Epoch 2/500
# 62/62 [==============================] - 0s 2ms/step - loss: 32.5877 - y1_output_loss: 12.4673 - y2_output_loss: 20.1204 - y1_output_root_mean_squared_error: 3.5309 - y2_output_root_mean_squared_error: 4.4856 - val_loss: 50.4106 - val_y1_output_loss: 13.8323 - val_y2_output_loss: 36.5783 - val_y1_output_root_mean_squared_error: 3.7192 - val_y2_output_root_mean_squared_error: 6.0480
# Epoch 3/500
# 62/62 [==============================] - 0s 3ms/step - loss: 23.1331 - y1_output_loss: 9.3543 - y2_output_loss: 13.7787 - y1_output_root_mean_squared_error: 3.0585 - y2_output_root_mean_squared_error: 3.7120 - val_loss: 30.6141 - val_y1_output_loss: 10.3758 - val_y2_output_loss: 20.2383 - val_y1_output_root_mean_squared_error: 3.2212 - val_y2_output_root_mean_squared_error: 4.4987
# Epoch 4/500
# 62/62 [==============================] - 0s 3ms/step - loss: 26.1212 - y1_output_loss: 9.8611 - y2_output_loss: 16.2601 - y1_output_root_mean_squared_error: 3.1402 - y2_output_root_mean_squared_error: 4.0324 - val_loss: 37.9393 - val_y1_output_loss: 12.6894 - val_y2_output_loss: 25.2499 - val_y1_output_root_mean_squared_error: 3.5622 - val_y2_output_root_mean_squared_error: 5.0249
# Epoch 5/500
# 62/62 [==============================] - 0s 2ms/step - loss: 21.1670 - y1_output_loss: 8.6024 - y2_output_loss: 12.5646 - y1_output_root_mean_squared_error: 2.9330 - y2_output_root_mean_squared_error: 3.5447 - val_loss: 24.2937 - val_y1_output_loss: 9.5399 - val_y2_output_loss: 14.7538 - val_y1_output_root_mean_squared_error: 3.0887 - val_y2_output_root_mean_squared_error: 3.8411
# Epoch 6/500
# 62/62 [==============================] - 0s 2ms/step - loss: 24.7602 - y1_output_loss: 9.1434 - y2_output_loss: 15.6168 - y1_output_root_mean_squared_error: 3.0238 - y2_output_root_mean_squared_error: 3.9518 - val_loss: 38.7177 - val_y1_output_loss: 12.0157 - val_y2_output_loss: 26.7020 - val_y1_output_root_mean_squared_error: 3.4664 - val_y2_output_root_mean_squared_error: 5.1674
# Epoch 7/500
# 62/62 [==============================] - 0s 2ms/step - loss: 20.7989 - y1_output_loss: 8.5540 - y2_output_loss: 12.2448 - y1_output_root_mean_squared_error: 2.9247 - y2_output_root_mean_squared_error: 3.4993 - val_loss: 20.9351 - val_y1_output_loss: 9.2939 - val_y2_output_loss: 11.6413 - val_y1_output_root_mean_squared_error: 3.0486 - val_y2_output_root_mean_squared_error: 3.4119
# Epoch 8/500
# 62/62 [==============================] - 0s 2ms/step - loss: 20.2351 - y1_output_loss: 8.0526 - y2_output_loss: 12.1825 - y1_output_root_mean_squared_error: 2.8377 - y2_output_root_mean_squared_error: 3.4903 - val_loss: 18.7688 - val_y1_output_loss: 7.8727 - val_y2_output_loss: 10.8961 - val_y1_output_root_mean_squared_error: 2.8058 - val_y2_output_root_mean_squared_error: 3.3009
# Epoch 9/500
# 62/62 [==============================] - 0s 2ms/step - loss: 19.6738 - y1_output_loss: 7.8873 - y2_output_loss: 11.7865 - y1_output_root_mean_squared_error: 2.8084 - y2_output_root_mean_squared_error: 3.4331 - val_loss: 19.1148 - val_y1_output_loss: 8.0114 - val_y2_output_loss: 11.1034 - val_y1_output_root_mean_squared_error: 2.8304 - val_y2_output_root_mean_squared_error: 3.3322
# Epoch 10/500
# 62/62 [==============================] - 0s 3ms/step - loss: 19.0813 - y1_output_loss: 7.7740 - y2_output_loss: 11.3074 - y1_output_root_mean_squared_error: 2.7882 - y2_output_root_mean_squared_error: 3.3626 - val_loss: 20.5221 - val_y1_output_loss: 8.0100 - val_y2_output_loss: 12.5121 - val_y1_output_root_mean_squared_error: 2.8302 - val_y2_output_root_mean_squared_error: 3.5373
# Epoch 11/500
# 62/62 [==============================] - 0s 3ms/step - loss: 19.9751 - y1_output_loss: 7.9732 - y2_output_loss: 12.0019 - y1_output_root_mean_squared_error: 2.8237 - y2_output_root_mean_squared_error: 3.4644 - val_loss: 24.5792 - val_y1_output_loss: 8.7775 - val_y2_output_loss: 15.8017 - val_y1_output_root_mean_squared_error: 2.9627 - val_y2_output_root_mean_squared_error: 3.9751
# Epoch 12/500
# 62/62 [==============================] - 0s 2ms/step - loss: 18.2988 - y1_output_loss: 7.4461 - y2_output_loss: 10.8527 - y1_output_root_mean_squared_error: 2.7288 - y2_output_root_mean_squared_error: 3.2943 - val_loss: 16.3661 - val_y1_output_loss: 7.0568 - val_y2_output_loss: 9.3093 - val_y1_output_root_mean_squared_error: 2.6565 - val_y2_output_root_mean_squared_error: 3.0511
# Epoch 13/500
# 62/62 [==============================] - 0s 3ms/step - loss: 19.1719 - y1_output_loss: 7.6095 - y2_output_loss: 11.5624 - y1_output_root_mean_squared_error: 2.7585 - y2_output_root_mean_squared_error: 3.4004 - val_loss: 35.5380 - val_y1_output_loss: 10.0695 - val_y2_output_loss: 25.4685 - val_y1_output_root_mean_squared_error: 3.1733 - val_y2_output_root_mean_squared_error: 5.0466
# Epoch 14/500
# 62/62 [==============================] - 0s 2ms/step - loss: 22.1061 - y1_output_loss: 8.0027 - y2_output_loss: 14.1035 - y1_output_root_mean_squared_error: 2.8289 - y2_output_root_mean_squared_error: 3.7555 - val_loss: 16.8723 - val_y1_output_loss: 7.0824 - val_y2_output_loss: 9.7898 - val_y1_output_root_mean_squared_error: 2.6613 - val_y2_output_root_mean_squared_error: 3.1289
# Epoch 15/500
# 62/62 [==============================] - 0s 3ms/step - loss: 16.5715 - y1_output_loss: 6.2943 - y2_output_loss: 10.2771 - y1_output_root_mean_squared_error: 2.5089 - y2_output_root_mean_squared_error: 3.2058 - val_loss: 17.8046 - val_y1_output_loss: 7.9145 - val_y2_output_loss: 9.8901 - val_y1_output_root_mean_squared_error: 2.8133 - val_y2_output_root_mean_squared_error: 3.1449
# Epoch 16/500
# 62/62 [==============================] - 0s 2ms/step - loss: 17.9872 - y1_output_loss: 6.8966 - y2_output_loss: 11.0905 - y1_output_root_mean_squared_error: 2.6261 - y2_output_root_mean_squared_error: 3.3302 - val_loss: 14.6915 - val_y1_output_loss: 5.8857 - val_y2_output_loss: 8.8058 - val_y1_output_root_mean_squared_error: 2.4260 - val_y2_output_root_mean_squared_error: 2.9675
# Epoch 17/500
# 62/62 [==============================] - 0s 3ms/step - loss: 15.2382 - y1_output_loss: 6.0192 - y2_output_loss: 9.2189 - y1_output_root_mean_squared_error: 2.4534 - y2_output_root_mean_squared_error: 3.0363 - val_loss: 29.4197 - val_y1_output_loss: 8.2561 - val_y2_output_loss: 21.1637 - val_y1_output_root_mean_squared_error: 2.8733 - val_y2_output_root_mean_squared_error: 4.6004
# Epoch 18/500
# 62/62 [==============================] - 0s 2ms/step - loss: 16.1171 - y1_output_loss: 6.1392 - y2_output_loss: 9.9778 - y1_output_root_mean_squared_error: 2.4777 - y2_output_root_mean_squared_error: 3.1588 - val_loss: 13.9878 - val_y1_output_loss: 5.1525 - val_y2_output_loss: 8.8353 - val_y1_output_root_mean_squared_error: 2.2699 - val_y2_output_root_mean_squared_error: 2.9724
# Epoch 19/500
# 62/62 [==============================] - 0s 2ms/step - loss: 21.2930 - y1_output_loss: 7.0464 - y2_output_loss: 14.2466 - y1_output_root_mean_squared_error: 2.6545 - y2_output_root_mean_squared_error: 3.7745 - val_loss: 20.5179 - val_y1_output_loss: 7.4376 - val_y2_output_loss: 13.0802 - val_y1_output_root_mean_squared_error: 2.7272 - val_y2_output_root_mean_squared_error: 3.6167
# Epoch 20/500
# 62/62 [==============================] - 0s 2ms/step - loss: 15.1300 - y1_output_loss: 5.9430 - y2_output_loss: 9.1870 - y1_output_root_mean_squared_error: 2.4378 - y2_output_root_mean_squared_error: 3.0310 - val_loss: 20.4133 - val_y1_output_loss: 6.1871 - val_y2_output_loss: 14.2262 - val_y1_output_root_mean_squared_error: 2.4874 - val_y2_output_root_mean_squared_error: 3.7718
# Epoch 21/500
# 62/62 [==============================] - 0s 3ms/step - loss: 14.5191 - y1_output_loss: 5.5610 - y2_output_loss: 8.9581 - y1_output_root_mean_squared_error: 2.3582 - y2_output_root_mean_squared_error: 2.9930 - val_loss: 49.2340 - val_y1_output_loss: 8.7883 - val_y2_output_loss: 40.4457 - val_y1_output_root_mean_squared_error: 2.9645 - val_y2_output_root_mean_squared_error: 6.3597
# Epoch 22/500
# 62/62 [==============================] - 0s 2ms/step - loss: 14.3292 - y1_output_loss: 5.2882 - y2_output_loss: 9.0410 - y1_output_root_mean_squared_error: 2.2996 - y2_output_root_mean_squared_error: 3.0068 - val_loss: 23.5199 - val_y1_output_loss: 7.7227 - val_y2_output_loss: 15.7972 - val_y1_output_root_mean_squared_error: 2.7790 - val_y2_output_root_mean_squared_error: 3.9746
# Epoch 23/500
# 62/62 [==============================] - 0s 3ms/step - loss: 15.5688 - y1_output_loss: 5.4045 - y2_output_loss: 10.1643 - y1_output_root_mean_squared_error: 2.3248 - y2_output_root_mean_squared_error: 3.1882 - val_loss: 11.7872 - val_y1_output_loss: 5.0692 - val_y2_output_loss: 6.7179 - val_y1_output_root_mean_squared_error: 2.2515 - val_y2_output_root_mean_squared_error: 2.5919
# Epoch 24/500
# 62/62 [==============================] - 0s 3ms/step - loss: 15.8950 - y1_output_loss: 5.5893 - y2_output_loss: 10.3056 - y1_output_root_mean_squared_error: 2.3642 - y2_output_root_mean_squared_error: 3.2102 - val_loss: 23.1184 - val_y1_output_loss: 9.6524 - val_y2_output_loss: 13.4660 - val_y1_output_root_mean_squared_error: 3.1068 - val_y2_output_root_mean_squared_error: 3.6696
# Epoch 25/500
# 62/62 [==============================] - 0s 3ms/step - loss: 14.9158 - y1_output_loss: 5.7733 - y2_output_loss: 9.1425 - y1_output_root_mean_squared_error: 2.4028 - y2_output_root_mean_squared_error: 3.0237 - val_loss: 12.2962 - val_y1_output_loss: 5.3688 - val_y2_output_loss: 6.9274 - val_y1_output_root_mean_squared_error: 2.3171 - val_y2_output_root_mean_squared_error: 2.6320
# Epoch 26/500
# 62/62 [==============================] - 0s 3ms/step - loss: 13.4470 - y1_output_loss: 4.8192 - y2_output_loss: 8.6278 - y1_output_root_mean_squared_error: 2.1953 - y2_output_root_mean_squared_error: 2.9373 - val_loss: 11.3832 - val_y1_output_loss: 4.7225 - val_y2_output_loss: 6.6608 - val_y1_output_root_mean_squared_error: 2.1731 - val_y2_output_root_mean_squared_error: 2.5808
# Epoch 27/500
# 62/62 [==============================] - 0s 3ms/step - loss: 14.7444 - y1_output_loss: 4.8345 - y2_output_loss: 9.9100 - y1_output_root_mean_squared_error: 2.1987 - y2_output_root_mean_squared_error: 3.1480 - val_loss: 11.8563 - val_y1_output_loss: 4.8924 - val_y2_output_loss: 6.9640 - val_y1_output_root_mean_squared_error: 2.2119 - val_y2_output_root_mean_squared_error: 2.6389
# Epoch 28/500
# 62/62 [==============================] - 0s 2ms/step - loss: 13.7320 - y1_output_loss: 4.8568 - y2_output_loss: 8.8753 - y1_output_root_mean_squared_error: 2.2038 - y2_output_root_mean_squared_error: 2.9791 - val_loss: 18.3536 - val_y1_output_loss: 7.2205 - val_y2_output_loss: 11.1331 - val_y1_output_root_mean_squared_error: 2.6871 - val_y2_output_root_mean_squared_error: 3.3366
# Epoch 29/500
# 62/62 [==============================] - 0s 3ms/step - loss: 11.3765 - y1_output_loss: 4.0535 - y2_output_loss: 7.3230 - y1_output_root_mean_squared_error: 2.0133 - y2_output_root_mean_squared_error: 2.7061 - val_loss: 10.0579 - val_y1_output_loss: 3.6993 - val_y2_output_loss: 6.3585 - val_y1_output_root_mean_squared_error: 1.9234 - val_y2_output_root_mean_squared_error: 2.5216
# Epoch 30/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.8941 - y1_output_loss: 3.5219 - y2_output_loss: 6.3722 - y1_output_root_mean_squared_error: 1.8767 - y2_output_root_mean_squared_error: 2.5243 - val_loss: 8.8816 - val_y1_output_loss: 3.4191 - val_y2_output_loss: 5.4625 - val_y1_output_root_mean_squared_error: 1.8491 - val_y2_output_root_mean_squared_error: 2.3372
# Epoch 31/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.8709 - y1_output_loss: 3.8968 - y2_output_loss: 6.9741 - y1_output_root_mean_squared_error: 1.9740 - y2_output_root_mean_squared_error: 2.6409 - val_loss: 8.7259 - val_y1_output_loss: 3.3706 - val_y2_output_loss: 5.3553 - val_y1_output_root_mean_squared_error: 1.8359 - val_y2_output_root_mean_squared_error: 2.3142
# Epoch 32/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.6626 - y1_output_loss: 3.4855 - y2_output_loss: 6.1771 - y1_output_root_mean_squared_error: 1.8669 - y2_output_root_mean_squared_error: 2.4854 - val_loss: 9.2986 - val_y1_output_loss: 3.0715 - val_y2_output_loss: 6.2271 - val_y1_output_root_mean_squared_error: 1.7526 - val_y2_output_root_mean_squared_error: 2.4954
# Epoch 33/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.7850 - y1_output_loss: 3.4716 - y2_output_loss: 7.3134 - y1_output_root_mean_squared_error: 1.8632 - y2_output_root_mean_squared_error: 2.7043 - val_loss: 22.8526 - val_y1_output_loss: 7.2891 - val_y2_output_loss: 15.5635 - val_y1_output_root_mean_squared_error: 2.6998 - val_y2_output_root_mean_squared_error: 3.9451
# Epoch 34/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.5657 - y1_output_loss: 3.2741 - y2_output_loss: 6.2916 - y1_output_root_mean_squared_error: 1.8094 - y2_output_root_mean_squared_error: 2.5083 - val_loss: 14.8214 - val_y1_output_loss: 4.4322 - val_y2_output_loss: 10.3892 - val_y1_output_root_mean_squared_error: 2.1053 - val_y2_output_root_mean_squared_error: 3.2232
# Epoch 35/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.0737 - y1_output_loss: 2.8128 - y2_output_loss: 5.2609 - y1_output_root_mean_squared_error: 1.6771 - y2_output_root_mean_squared_error: 2.2937 - val_loss: 9.9477 - val_y1_output_loss: 3.8477 - val_y2_output_loss: 6.1000 - val_y1_output_root_mean_squared_error: 1.9615 - val_y2_output_root_mean_squared_error: 2.4698
# Epoch 36/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.0948 - y1_output_loss: 3.1527 - y2_output_loss: 5.9421 - y1_output_root_mean_squared_error: 1.7756 - y2_output_root_mean_squared_error: 2.4376 - val_loss: 11.9675 - val_y1_output_loss: 3.6118 - val_y2_output_loss: 8.3557 - val_y1_output_root_mean_squared_error: 1.9005 - val_y2_output_root_mean_squared_error: 2.8906
# Epoch 37/500
# 62/62 [==============================] - 0s 2ms/step - loss: 9.8113 - y1_output_loss: 3.1937 - y2_output_loss: 6.6176 - y1_output_root_mean_squared_error: 1.7871 - y2_output_root_mean_squared_error: 2.5725 - val_loss: 20.3207 - val_y1_output_loss: 4.7133 - val_y2_output_loss: 15.6074 - val_y1_output_root_mean_squared_error: 2.1710 - val_y2_output_root_mean_squared_error: 3.9506
# Epoch 38/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.1840 - y1_output_loss: 2.7531 - y2_output_loss: 5.4309 - y1_output_root_mean_squared_error: 1.6592 - y2_output_root_mean_squared_error: 2.3304 - val_loss: 12.4279 - val_y1_output_loss: 3.9052 - val_y2_output_loss: 8.5227 - val_y1_output_root_mean_squared_error: 1.9762 - val_y2_output_root_mean_squared_error: 2.9194
# Epoch 39/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.9215 - y1_output_loss: 2.9485 - y2_output_loss: 5.9730 - y1_output_root_mean_squared_error: 1.7171 - y2_output_root_mean_squared_error: 2.4440 - val_loss: 18.0011 - val_y1_output_loss: 6.7828 - val_y2_output_loss: 11.2183 - val_y1_output_root_mean_squared_error: 2.6044 - val_y2_output_root_mean_squared_error: 3.3494
# Epoch 40/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.1954 - y1_output_loss: 2.7009 - y2_output_loss: 5.4945 - y1_output_root_mean_squared_error: 1.6434 - y2_output_root_mean_squared_error: 2.3440 - val_loss: 26.7333 - val_y1_output_loss: 6.8323 - val_y2_output_loss: 19.9010 - val_y1_output_root_mean_squared_error: 2.6139 - val_y2_output_root_mean_squared_error: 4.4611
# Epoch 41/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.8515 - y1_output_loss: 2.8703 - y2_output_loss: 5.9811 - y1_output_root_mean_squared_error: 1.6942 - y2_output_root_mean_squared_error: 2.4456 - val_loss: 14.1023 - val_y1_output_loss: 4.6533 - val_y2_output_loss: 9.4489 - val_y1_output_root_mean_squared_error: 2.1572 - val_y2_output_root_mean_squared_error: 3.0739
# Epoch 42/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.1578 - y1_output_loss: 2.4451 - y2_output_loss: 4.7128 - y1_output_root_mean_squared_error: 1.5637 - y2_output_root_mean_squared_error: 2.1709 - val_loss: 8.9684 - val_y1_output_loss: 2.3276 - val_y2_output_loss: 6.6407 - val_y1_output_root_mean_squared_error: 1.5257 - val_y2_output_root_mean_squared_error: 2.5770
# Epoch 43/500
# 62/62 [==============================] - 0s 3ms/step - loss: 11.4379 - y1_output_loss: 3.7130 - y2_output_loss: 7.7249 - y1_output_root_mean_squared_error: 1.9269 - y2_output_root_mean_squared_error: 2.7794 - val_loss: 6.9105 - val_y1_output_loss: 2.3356 - val_y2_output_loss: 4.5749 - val_y1_output_root_mean_squared_error: 1.5283 - val_y2_output_root_mean_squared_error: 2.1389
# Epoch 44/500
# 62/62 [==============================] - 0s 2ms/step - loss: 8.9886 - y1_output_loss: 2.7840 - y2_output_loss: 6.2046 - y1_output_root_mean_squared_error: 1.6685 - y2_output_root_mean_squared_error: 2.4909 - val_loss: 25.9311 - val_y1_output_loss: 9.4067 - val_y2_output_loss: 16.5244 - val_y1_output_root_mean_squared_error: 3.0670 - val_y2_output_root_mean_squared_error: 4.0650
# Epoch 45/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.8438 - y1_output_loss: 2.7370 - y2_output_loss: 6.1068 - y1_output_root_mean_squared_error: 1.6544 - y2_output_root_mean_squared_error: 2.4712 - val_loss: 7.1779 - val_y1_output_loss: 2.4397 - val_y2_output_loss: 4.7382 - val_y1_output_root_mean_squared_error: 1.5619 - val_y2_output_root_mean_squared_error: 2.1767
# Epoch 46/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.4588 - y1_output_loss: 2.2353 - y2_output_loss: 4.2235 - y1_output_root_mean_squared_error: 1.4951 - y2_output_root_mean_squared_error: 2.0551 - val_loss: 10.1470 - val_y1_output_loss: 4.4508 - val_y2_output_loss: 5.6962 - val_y1_output_root_mean_squared_error: 2.1097 - val_y2_output_root_mean_squared_error: 2.3867
# Epoch 47/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.4407 - y1_output_loss: 2.7921 - y2_output_loss: 5.6485 - y1_output_root_mean_squared_error: 1.6710 - y2_output_root_mean_squared_error: 2.3767 - val_loss: 10.8806 - val_y1_output_loss: 3.7162 - val_y2_output_loss: 7.1644 - val_y1_output_root_mean_squared_error: 1.9277 - val_y2_output_root_mean_squared_error: 2.6766
# Epoch 48/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.9539 - y1_output_loss: 2.2229 - y2_output_loss: 4.7311 - y1_output_root_mean_squared_error: 1.4909 - y2_output_root_mean_squared_error: 2.1751 - val_loss: 15.6008 - val_y1_output_loss: 3.9990 - val_y2_output_loss: 11.6018 - val_y1_output_root_mean_squared_error: 1.9998 - val_y2_output_root_mean_squared_error: 3.4061
# Epoch 49/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.2101 - y1_output_loss: 2.1998 - y2_output_loss: 5.0103 - y1_output_root_mean_squared_error: 1.4832 - y2_output_root_mean_squared_error: 2.2384 - val_loss: 16.9599 - val_y1_output_loss: 4.9778 - val_y2_output_loss: 11.9821 - val_y1_output_root_mean_squared_error: 2.2311 - val_y2_output_root_mean_squared_error: 3.4615
# Epoch 50/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.5577 - y1_output_loss: 1.9466 - y2_output_loss: 4.6111 - y1_output_root_mean_squared_error: 1.3952 - y2_output_root_mean_squared_error: 2.1473 - val_loss: 6.1601 - val_y1_output_loss: 1.8739 - val_y2_output_loss: 4.2862 - val_y1_output_root_mean_squared_error: 1.3689 - val_y2_output_root_mean_squared_error: 2.0703
# Epoch 51/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.4724 - y1_output_loss: 1.7865 - y2_output_loss: 4.6859 - y1_output_root_mean_squared_error: 1.3366 - y2_output_root_mean_squared_error: 2.1647 - val_loss: 9.2277 - val_y1_output_loss: 2.2470 - val_y2_output_loss: 6.9808 - val_y1_output_root_mean_squared_error: 1.4990 - val_y2_output_root_mean_squared_error: 2.6421
# Epoch 52/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.2811 - y1_output_loss: 1.9339 - y2_output_loss: 4.3472 - y1_output_root_mean_squared_error: 1.3906 - y2_output_root_mean_squared_error: 2.0850 - val_loss: 5.3148 - val_y1_output_loss: 1.7073 - val_y2_output_loss: 3.6075 - val_y1_output_root_mean_squared_error: 1.3066 - val_y2_output_root_mean_squared_error: 1.8993
# Epoch 53/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.0041 - y1_output_loss: 1.8525 - y2_output_loss: 4.1516 - y1_output_root_mean_squared_error: 1.3611 - y2_output_root_mean_squared_error: 2.0375 - val_loss: 8.6079 - val_y1_output_loss: 3.0993 - val_y2_output_loss: 5.5087 - val_y1_output_root_mean_squared_error: 1.7605 - val_y2_output_root_mean_squared_error: 2.3471
# Epoch 54/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.8779 - y1_output_loss: 1.8214 - y2_output_loss: 4.0565 - y1_output_root_mean_squared_error: 1.3496 - y2_output_root_mean_squared_error: 2.0141 - val_loss: 15.7300 - val_y1_output_loss: 3.2522 - val_y2_output_loss: 12.4778 - val_y1_output_root_mean_squared_error: 1.8034 - val_y2_output_root_mean_squared_error: 3.5324
# Epoch 55/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.7057 - y1_output_loss: 2.6080 - y2_output_loss: 7.0977 - y1_output_root_mean_squared_error: 1.6149 - y2_output_root_mean_squared_error: 2.6642 - val_loss: 6.2855 - val_y1_output_loss: 2.1305 - val_y2_output_loss: 4.1550 - val_y1_output_root_mean_squared_error: 1.4596 - val_y2_output_root_mean_squared_error: 2.0384
# Epoch 56/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.8873 - y1_output_loss: 1.7814 - y2_output_loss: 4.1059 - y1_output_root_mean_squared_error: 1.3347 - y2_output_root_mean_squared_error: 2.0263 - val_loss: 5.8765 - val_y1_output_loss: 1.6788 - val_y2_output_loss: 4.1977 - val_y1_output_root_mean_squared_error: 1.2957 - val_y2_output_root_mean_squared_error: 2.0488
# Epoch 57/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.2575 - y1_output_loss: 2.2245 - y2_output_loss: 5.0330 - y1_output_root_mean_squared_error: 1.4915 - y2_output_root_mean_squared_error: 2.2434 - val_loss: 6.4147 - val_y1_output_loss: 2.3029 - val_y2_output_loss: 4.1118 - val_y1_output_root_mean_squared_error: 1.5175 - val_y2_output_root_mean_squared_error: 2.0278
# Epoch 58/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.2648 - y1_output_loss: 1.8618 - y2_output_loss: 4.4029 - y1_output_root_mean_squared_error: 1.3645 - y2_output_root_mean_squared_error: 2.0983 - val_loss: 7.0825 - val_y1_output_loss: 2.4206 - val_y2_output_loss: 4.6618 - val_y1_output_root_mean_squared_error: 1.5558 - val_y2_output_root_mean_squared_error: 2.1591
# Epoch 59/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.7972 - y1_output_loss: 2.0076 - y2_output_loss: 4.7896 - y1_output_root_mean_squared_error: 1.4169 - y2_output_root_mean_squared_error: 2.1885 - val_loss: 8.4505 - val_y1_output_loss: 3.4760 - val_y2_output_loss: 4.9745 - val_y1_output_root_mean_squared_error: 1.8644 - val_y2_output_root_mean_squared_error: 2.2303
# Epoch 60/500
# 62/62 [==============================] - 0s 2ms/step - loss: 6.0031 - y1_output_loss: 1.6837 - y2_output_loss: 4.3194 - y1_output_root_mean_squared_error: 1.2976 - y2_output_root_mean_squared_error: 2.0783 - val_loss: 4.6128 - val_y1_output_loss: 1.3609 - val_y2_output_loss: 3.2519 - val_y1_output_root_mean_squared_error: 1.1666 - val_y2_output_root_mean_squared_error: 1.8033
# Epoch 61/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.9802 - y1_output_loss: 1.8514 - y2_output_loss: 4.1288 - y1_output_root_mean_squared_error: 1.3607 - y2_output_root_mean_squared_error: 2.0319 - val_loss: 7.0189 - val_y1_output_loss: 2.6762 - val_y2_output_loss: 4.3427 - val_y1_output_root_mean_squared_error: 1.6359 - val_y2_output_root_mean_squared_error: 2.0839
# Epoch 62/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.9708 - y1_output_loss: 1.5786 - y2_output_loss: 4.3922 - y1_output_root_mean_squared_error: 1.2564 - y2_output_root_mean_squared_error: 2.0958 - val_loss: 43.5182 - val_y1_output_loss: 6.9417 - val_y2_output_loss: 36.5765 - val_y1_output_root_mean_squared_error: 2.6347 - val_y2_output_root_mean_squared_error: 6.0479
# Epoch 63/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.3485 - y1_output_loss: 1.7320 - y2_output_loss: 4.6165 - y1_output_root_mean_squared_error: 1.3160 - y2_output_root_mean_squared_error: 2.1486 - val_loss: 23.3596 - val_y1_output_loss: 4.6330 - val_y2_output_loss: 18.7266 - val_y1_output_root_mean_squared_error: 2.1524 - val_y2_output_root_mean_squared_error: 4.3274
# Epoch 64/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.7872 - y1_output_loss: 1.9008 - y2_output_loss: 4.8863 - y1_output_root_mean_squared_error: 1.3787 - y2_output_root_mean_squared_error: 2.2105 - val_loss: 7.1603 - val_y1_output_loss: 1.6988 - val_y2_output_loss: 5.4615 - val_y1_output_root_mean_squared_error: 1.3034 - val_y2_output_root_mean_squared_error: 2.3370
# Epoch 65/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.6985 - y1_output_loss: 1.4145 - y2_output_loss: 4.2840 - y1_output_root_mean_squared_error: 1.1893 - y2_output_root_mean_squared_error: 2.0698 - val_loss: 5.7630 - val_y1_output_loss: 1.4993 - val_y2_output_loss: 4.2637 - val_y1_output_root_mean_squared_error: 1.2245 - val_y2_output_root_mean_squared_error: 2.0649
# Epoch 66/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.5860 - y1_output_loss: 1.4282 - y2_output_loss: 4.1577 - y1_output_root_mean_squared_error: 1.1951 - y2_output_root_mean_squared_error: 2.0391 - val_loss: 5.7992 - val_y1_output_loss: 1.6364 - val_y2_output_loss: 4.1628 - val_y1_output_root_mean_squared_error: 1.2792 - val_y2_output_root_mean_squared_error: 2.0403
# Epoch 67/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.7437 - y1_output_loss: 1.4587 - y2_output_loss: 4.2850 - y1_output_root_mean_squared_error: 1.2078 - y2_output_root_mean_squared_error: 2.0700 - val_loss: 9.1185 - val_y1_output_loss: 1.8654 - val_y2_output_loss: 7.2531 - val_y1_output_root_mean_squared_error: 1.3658 - val_y2_output_root_mean_squared_error: 2.6932
# Epoch 68/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.0366 - y1_output_loss: 2.9277 - y2_output_loss: 7.1088 - y1_output_root_mean_squared_error: 1.7111 - y2_output_root_mean_squared_error: 2.6662 - val_loss: 8.8709 - val_y1_output_loss: 2.8149 - val_y2_output_loss: 6.0560 - val_y1_output_root_mean_squared_error: 1.6778 - val_y2_output_root_mean_squared_error: 2.4609
# Epoch 69/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.8397 - y1_output_loss: 1.4567 - y2_output_loss: 3.3831 - y1_output_root_mean_squared_error: 1.2069 - y2_output_root_mean_squared_error: 1.8393 - val_loss: 4.4869 - val_y1_output_loss: 1.3072 - val_y2_output_loss: 3.1797 - val_y1_output_root_mean_squared_error: 1.1433 - val_y2_output_root_mean_squared_error: 1.7832
# Epoch 70/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.3273 - y1_output_loss: 1.0978 - y2_output_loss: 3.2294 - y1_output_root_mean_squared_error: 1.0478 - y2_output_root_mean_squared_error: 1.7971 - val_loss: 5.7606 - val_y1_output_loss: 1.3570 - val_y2_output_loss: 4.4036 - val_y1_output_root_mean_squared_error: 1.1649 - val_y2_output_root_mean_squared_error: 2.0985
# Epoch 71/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.2418 - y1_output_loss: 1.3789 - y2_output_loss: 3.8629 - y1_output_root_mean_squared_error: 1.1743 - y2_output_root_mean_squared_error: 1.9654 - val_loss: 4.5674 - val_y1_output_loss: 1.4471 - val_y2_output_loss: 3.1203 - val_y1_output_root_mean_squared_error: 1.2029 - val_y2_output_root_mean_squared_error: 1.7664
# Epoch 72/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.3422 - y1_output_loss: 1.8107 - y2_output_loss: 4.5315 - y1_output_root_mean_squared_error: 1.3456 - y2_output_root_mean_squared_error: 2.1287 - val_loss: 4.3502 - val_y1_output_loss: 1.2729 - val_y2_output_loss: 3.0774 - val_y1_output_root_mean_squared_error: 1.1282 - val_y2_output_root_mean_squared_error: 1.7542
# Epoch 73/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.3113 - y1_output_loss: 2.0317 - y2_output_loss: 4.2796 - y1_output_root_mean_squared_error: 1.4254 - y2_output_root_mean_squared_error: 2.0687 - val_loss: 6.1265 - val_y1_output_loss: 1.1768 - val_y2_output_loss: 4.9497 - val_y1_output_root_mean_squared_error: 1.0848 - val_y2_output_root_mean_squared_error: 2.2248
# Epoch 74/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.4285 - y1_output_loss: 1.1206 - y2_output_loss: 3.3079 - y1_output_root_mean_squared_error: 1.0586 - y2_output_root_mean_squared_error: 1.8188 - val_loss: 5.6271 - val_y1_output_loss: 1.5237 - val_y2_output_loss: 4.1034 - val_y1_output_root_mean_squared_error: 1.2344 - val_y2_output_root_mean_squared_error: 2.0257
# Epoch 75/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.8828 - y1_output_loss: 1.2182 - y2_output_loss: 3.6647 - y1_output_root_mean_squared_error: 1.1037 - y2_output_root_mean_squared_error: 1.9143 - val_loss: 3.8687 - val_y1_output_loss: 0.9740 - val_y2_output_loss: 2.8947 - val_y1_output_root_mean_squared_error: 0.9869 - val_y2_output_root_mean_squared_error: 1.7014
# Epoch 76/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.8813 - y1_output_loss: 1.5381 - y2_output_loss: 4.3432 - y1_output_root_mean_squared_error: 1.2402 - y2_output_root_mean_squared_error: 2.0840 - val_loss: 14.8954 - val_y1_output_loss: 2.7083 - val_y2_output_loss: 12.1871 - val_y1_output_root_mean_squared_error: 1.6457 - val_y2_output_root_mean_squared_error: 3.4910
# Epoch 77/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.0018 - y1_output_loss: 0.9554 - y2_output_loss: 3.0464 - y1_output_root_mean_squared_error: 0.9774 - y2_output_root_mean_squared_error: 1.7454 - val_loss: 3.7801 - val_y1_output_loss: 1.1049 - val_y2_output_loss: 2.6752 - val_y1_output_root_mean_squared_error: 1.0511 - val_y2_output_root_mean_squared_error: 1.6356
# Epoch 78/500
# 62/62 [==============================] - 0s 2ms/step - loss: 4.6974 - y1_output_loss: 1.1494 - y2_output_loss: 3.5480 - y1_output_root_mean_squared_error: 1.0721 - y2_output_root_mean_squared_error: 1.8836 - val_loss: 3.6097 - val_y1_output_loss: 0.8421 - val_y2_output_loss: 2.7676 - val_y1_output_root_mean_squared_error: 0.9177 - val_y2_output_root_mean_squared_error: 1.6636
# Epoch 79/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.7471 - y1_output_loss: 0.8922 - y2_output_loss: 2.8549 - y1_output_root_mean_squared_error: 0.9446 - y2_output_root_mean_squared_error: 1.6896 - val_loss: 7.4274 - val_y1_output_loss: 1.4581 - val_y2_output_loss: 5.9693 - val_y1_output_root_mean_squared_error: 1.2075 - val_y2_output_root_mean_squared_error: 2.4432
# Epoch 80/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.2547 - y1_output_loss: 1.8884 - y2_output_loss: 4.3663 - y1_output_root_mean_squared_error: 1.3742 - y2_output_root_mean_squared_error: 2.0896 - val_loss: 4.2208 - val_y1_output_loss: 1.2198 - val_y2_output_loss: 3.0010 - val_y1_output_root_mean_squared_error: 1.1044 - val_y2_output_root_mean_squared_error: 1.7324
# Epoch 81/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.8304 - y1_output_loss: 1.0470 - y2_output_loss: 2.7834 - y1_output_root_mean_squared_error: 1.0232 - y2_output_root_mean_squared_error: 1.6684 - val_loss: 3.6012 - val_y1_output_loss: 0.9136 - val_y2_output_loss: 2.6876 - val_y1_output_root_mean_squared_error: 0.9558 - val_y2_output_root_mean_squared_error: 1.6394
# Epoch 82/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.4290 - y1_output_loss: 1.1849 - y2_output_loss: 3.2442 - y1_output_root_mean_squared_error: 1.0885 - y2_output_root_mean_squared_error: 1.8012 - val_loss: 11.2006 - val_y1_output_loss: 2.8126 - val_y2_output_loss: 8.3879 - val_y1_output_root_mean_squared_error: 1.6771 - val_y2_output_root_mean_squared_error: 2.8962
# Epoch 83/500
# 62/62 [==============================] - 0s 2ms/step - loss: 5.0461 - y1_output_loss: 1.3086 - y2_output_loss: 3.7374 - y1_output_root_mean_squared_error: 1.1440 - y2_output_root_mean_squared_error: 1.9332 - val_loss: 19.2404 - val_y1_output_loss: 4.8073 - val_y2_output_loss: 14.4331 - val_y1_output_root_mean_squared_error: 2.1925 - val_y2_output_root_mean_squared_error: 3.7991
# Epoch 84/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.7338 - y1_output_loss: 1.1031 - y2_output_loss: 3.6307 - y1_output_root_mean_squared_error: 1.0503 - y2_output_root_mean_squared_error: 1.9054 - val_loss: 6.2218 - val_y1_output_loss: 1.9908 - val_y2_output_loss: 4.2310 - val_y1_output_root_mean_squared_error: 1.4110 - val_y2_output_root_mean_squared_error: 2.0569
# Epoch 85/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.9245 - y1_output_loss: 1.9069 - y2_output_loss: 5.0175 - y1_output_root_mean_squared_error: 1.3809 - y2_output_root_mean_squared_error: 2.2400 - val_loss: 7.7778 - val_y1_output_loss: 0.9450 - val_y2_output_loss: 6.8327 - val_y1_output_root_mean_squared_error: 0.9721 - val_y2_output_root_mean_squared_error: 2.6140
# Epoch 86/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.7249 - y1_output_loss: 3.0397 - y2_output_loss: 7.6852 - y1_output_root_mean_squared_error: 1.7435 - y2_output_root_mean_squared_error: 2.7722 - val_loss: 4.2517 - val_y1_output_loss: 0.8640 - val_y2_output_loss: 3.3877 - val_y1_output_root_mean_squared_error: 0.9295 - val_y2_output_root_mean_squared_error: 1.8406
# Epoch 87/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.5252 - y1_output_loss: 0.8070 - y2_output_loss: 2.7182 - y1_output_root_mean_squared_error: 0.8983 - y2_output_root_mean_squared_error: 1.6487 - val_loss: 3.2904 - val_y1_output_loss: 0.7705 - val_y2_output_loss: 2.5199 - val_y1_output_root_mean_squared_error: 0.8778 - val_y2_output_root_mean_squared_error: 1.5874
# Epoch 88/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.6401 - y1_output_loss: 1.9879 - y2_output_loss: 4.6522 - y1_output_root_mean_squared_error: 1.4099 - y2_output_root_mean_squared_error: 2.1569 - val_loss: 3.6947 - val_y1_output_loss: 0.7819 - val_y2_output_loss: 2.9128 - val_y1_output_root_mean_squared_error: 0.8843 - val_y2_output_root_mean_squared_error: 1.7067
# Epoch 89/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.6759 - y1_output_loss: 0.7941 - y2_output_loss: 2.8819 - y1_output_root_mean_squared_error: 0.8911 - y2_output_root_mean_squared_error: 1.6976 - val_loss: 3.4133 - val_y1_output_loss: 0.7953 - val_y2_output_loss: 2.6180 - val_y1_output_root_mean_squared_error: 0.8918 - val_y2_output_root_mean_squared_error: 1.6180
# Epoch 90/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.1486 - y1_output_loss: 0.8002 - y2_output_loss: 2.3484 - y1_output_root_mean_squared_error: 0.8945 - y2_output_root_mean_squared_error: 1.5325 - val_loss: 10.1683 - val_y1_output_loss: 2.5109 - val_y2_output_loss: 7.6575 - val_y1_output_root_mean_squared_error: 1.5846 - val_y2_output_root_mean_squared_error: 2.7672
# Epoch 91/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.5406 - y1_output_loss: 2.2345 - y2_output_loss: 5.3060 - y1_output_root_mean_squared_error: 1.4948 - y2_output_root_mean_squared_error: 2.3035 - val_loss: 3.8247 - val_y1_output_loss: 0.6967 - val_y2_output_loss: 3.1280 - val_y1_output_root_mean_squared_error: 0.8347 - val_y2_output_root_mean_squared_error: 1.7686
# Epoch 92/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.3279 - y1_output_loss: 0.8366 - y2_output_loss: 2.4913 - y1_output_root_mean_squared_error: 0.9147 - y2_output_root_mean_squared_error: 1.5784 - val_loss: 8.2170 - val_y1_output_loss: 2.5482 - val_y2_output_loss: 5.6688 - val_y1_output_root_mean_squared_error: 1.5963 - val_y2_output_root_mean_squared_error: 2.3809
# Epoch 93/500
# 62/62 [==============================] - 0s 2ms/step - loss: 3.5986 - y1_output_loss: 0.9446 - y2_output_loss: 2.6540 - y1_output_root_mean_squared_error: 0.9719 - y2_output_root_mean_squared_error: 1.6291 - val_loss: 23.4785 - val_y1_output_loss: 3.2497 - val_y2_output_loss: 20.2288 - val_y1_output_root_mean_squared_error: 1.8027 - val_y2_output_root_mean_squared_error: 4.4976
# Epoch 94/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.1045 - y1_output_loss: 0.8846 - y2_output_loss: 3.2198 - y1_output_root_mean_squared_error: 0.9406 - y2_output_root_mean_squared_error: 1.7944 - val_loss: 2.9438 - val_y1_output_loss: 0.6825 - val_y2_output_loss: 2.2613 - val_y1_output_root_mean_squared_error: 0.8261 - val_y2_output_root_mean_squared_error: 1.5038
# Epoch 95/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.6937 - y1_output_loss: 0.8757 - y2_output_loss: 2.8180 - y1_output_root_mean_squared_error: 0.9358 - y2_output_root_mean_squared_error: 1.6787 - val_loss: 3.7310 - val_y1_output_loss: 0.8410 - val_y2_output_loss: 2.8900 - val_y1_output_root_mean_squared_error: 0.9171 - val_y2_output_root_mean_squared_error: 1.7000
# Epoch 96/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.7483 - y1_output_loss: 0.5474 - y2_output_loss: 2.2009 - y1_output_root_mean_squared_error: 0.7399 - y2_output_root_mean_squared_error: 1.4835 - val_loss: 4.3536 - val_y1_output_loss: 1.0298 - val_y2_output_loss: 3.3238 - val_y1_output_root_mean_squared_error: 1.0148 - val_y2_output_root_mean_squared_error: 1.8231
# Epoch 97/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.7785 - y1_output_loss: 0.9484 - y2_output_loss: 2.8302 - y1_output_root_mean_squared_error: 0.9738 - y2_output_root_mean_squared_error: 1.6823 - val_loss: 6.9928 - val_y1_output_loss: 2.5874 - val_y2_output_loss: 4.4054 - val_y1_output_root_mean_squared_error: 1.6085 - val_y2_output_root_mean_squared_error: 2.0989
# Epoch 98/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.3857 - y1_output_loss: 0.6859 - y2_output_loss: 2.6998 - y1_output_root_mean_squared_error: 0.8282 - y2_output_root_mean_squared_error: 1.6431 - val_loss: 5.7567 - val_y1_output_loss: 0.6824 - val_y2_output_loss: 5.0744 - val_y1_output_root_mean_squared_error: 0.8261 - val_y2_output_root_mean_squared_error: 2.2526
# Epoch 99/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.0239 - y1_output_loss: 1.3847 - y2_output_loss: 3.6392 - y1_output_root_mean_squared_error: 1.1767 - y2_output_root_mean_squared_error: 1.9077 - val_loss: 3.3687 - val_y1_output_loss: 0.9592 - val_y2_output_loss: 2.4096 - val_y1_output_root_mean_squared_error: 0.9794 - val_y2_output_root_mean_squared_error: 1.5523
# Epoch 100/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.1485 - y1_output_loss: 0.6909 - y2_output_loss: 2.4576 - y1_output_root_mean_squared_error: 0.8312 - y2_output_root_mean_squared_error: 1.5677 - val_loss: 4.1467 - val_y1_output_loss: 1.4604 - val_y2_output_loss: 2.6863 - val_y1_output_root_mean_squared_error: 1.2085 - val_y2_output_root_mean_squared_error: 1.6390
# Epoch 101/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.6274 - y1_output_loss: 0.6028 - y2_output_loss: 2.0246 - y1_output_root_mean_squared_error: 0.7764 - y2_output_root_mean_squared_error: 1.4229 - val_loss: 3.8802 - val_y1_output_loss: 0.6822 - val_y2_output_loss: 3.1980 - val_y1_output_root_mean_squared_error: 0.8260 - val_y2_output_root_mean_squared_error: 1.7883
# Epoch 102/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.1258 - y1_output_loss: 0.8088 - y2_output_loss: 2.3170 - y1_output_root_mean_squared_error: 0.8994 - y2_output_root_mean_squared_error: 1.5222 - val_loss: 8.6253 - val_y1_output_loss: 1.7077 - val_y2_output_loss: 6.9176 - val_y1_output_root_mean_squared_error: 1.3068 - val_y2_output_root_mean_squared_error: 2.6301
# Epoch 103/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.2437 - y1_output_loss: 0.7767 - y2_output_loss: 2.4669 - y1_output_root_mean_squared_error: 0.8813 - y2_output_root_mean_squared_error: 1.5707 - val_loss: 3.2603 - val_y1_output_loss: 0.8074 - val_y2_output_loss: 2.4529 - val_y1_output_root_mean_squared_error: 0.8986 - val_y2_output_root_mean_squared_error: 1.5662
# Epoch 104/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.1711 - y1_output_loss: 0.6611 - y2_output_loss: 2.5100 - y1_output_root_mean_squared_error: 0.8131 - y2_output_root_mean_squared_error: 1.5843 - val_loss: 2.8543 - val_y1_output_loss: 0.5553 - val_y2_output_loss: 2.2990 - val_y1_output_root_mean_squared_error: 0.7452 - val_y2_output_root_mean_squared_error: 1.5162
# Epoch 105/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.8931 - y1_output_loss: 0.6557 - y2_output_loss: 2.2374 - y1_output_root_mean_squared_error: 0.8098 - y2_output_root_mean_squared_error: 1.4958 - val_loss: 4.1248 - val_y1_output_loss: 1.0012 - val_y2_output_loss: 3.1235 - val_y1_output_root_mean_squared_error: 1.0006 - val_y2_output_root_mean_squared_error: 1.7674
# Epoch 106/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.7312 - y1_output_loss: 0.6364 - y2_output_loss: 2.0949 - y1_output_root_mean_squared_error: 0.7977 - y2_output_root_mean_squared_error: 1.4474 - val_loss: 3.0566 - val_y1_output_loss: 0.7105 - val_y2_output_loss: 2.3461 - val_y1_output_root_mean_squared_error: 0.8429 - val_y2_output_root_mean_squared_error: 1.5317
# Epoch 107/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.5620 - y1_output_loss: 0.5044 - y2_output_loss: 2.0575 - y1_output_root_mean_squared_error: 0.7102 - y2_output_root_mean_squared_error: 1.4344 - val_loss: 4.6880 - val_y1_output_loss: 1.4775 - val_y2_output_loss: 3.2106 - val_y1_output_root_mean_squared_error: 1.2155 - val_y2_output_root_mean_squared_error: 1.7918
# Epoch 108/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.7527 - y1_output_loss: 0.6372 - y2_output_loss: 2.1155 - y1_output_root_mean_squared_error: 0.7982 - y2_output_root_mean_squared_error: 1.4545 - val_loss: 3.1671 - val_y1_output_loss: 0.6344 - val_y2_output_loss: 2.5327 - val_y1_output_root_mean_squared_error: 0.7965 - val_y2_output_root_mean_squared_error: 1.5914
# Epoch 109/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.4173 - y1_output_loss: 0.5905 - y2_output_loss: 1.8268 - y1_output_root_mean_squared_error: 0.7685 - y2_output_root_mean_squared_error: 1.3516 - val_loss: 4.6514 - val_y1_output_loss: 0.6744 - val_y2_output_loss: 3.9771 - val_y1_output_root_mean_squared_error: 0.8212 - val_y2_output_root_mean_squared_error: 1.9943
# Epoch 110/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.8930 - y1_output_loss: 0.6476 - y2_output_loss: 2.2454 - y1_output_root_mean_squared_error: 0.8048 - y2_output_root_mean_squared_error: 1.4985 - val_loss: 2.5452 - val_y1_output_loss: 0.5497 - val_y2_output_loss: 1.9955 - val_y1_output_root_mean_squared_error: 0.7414 - val_y2_output_root_mean_squared_error: 1.4126
# Epoch 111/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.3731 - y1_output_loss: 0.5506 - y2_output_loss: 1.8225 - y1_output_root_mean_squared_error: 0.7421 - y2_output_root_mean_squared_error: 1.3500 - val_loss: 3.0366 - val_y1_output_loss: 0.5783 - val_y2_output_loss: 2.4583 - val_y1_output_root_mean_squared_error: 0.7605 - val_y2_output_root_mean_squared_error: 1.5679
# Epoch 112/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.5952 - y1_output_loss: 0.6091 - y2_output_loss: 1.9861 - y1_output_root_mean_squared_error: 0.7804 - y2_output_root_mean_squared_error: 1.4093 - val_loss: 2.7598 - val_y1_output_loss: 0.6476 - val_y2_output_loss: 2.1122 - val_y1_output_root_mean_squared_error: 0.8047 - val_y2_output_root_mean_squared_error: 1.4533
# Epoch 113/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.2532 - y1_output_loss: 0.5452 - y2_output_loss: 1.7081 - y1_output_root_mean_squared_error: 0.7384 - y2_output_root_mean_squared_error: 1.3069 - val_loss: 2.3635 - val_y1_output_loss: 0.6021 - val_y2_output_loss: 1.7614 - val_y1_output_root_mean_squared_error: 0.7759 - val_y2_output_root_mean_squared_error: 1.3272
# Epoch 114/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.5715 - y1_output_loss: 0.5673 - y2_output_loss: 2.0042 - y1_output_root_mean_squared_error: 0.7532 - y2_output_root_mean_squared_error: 1.4157 - val_loss: 5.4927 - val_y1_output_loss: 1.8734 - val_y2_output_loss: 3.6192 - val_y1_output_root_mean_squared_error: 1.3687 - val_y2_output_root_mean_squared_error: 1.9024
# Epoch 115/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.0778 - y1_output_loss: 0.6942 - y2_output_loss: 2.3836 - y1_output_root_mean_squared_error: 0.8332 - y2_output_root_mean_squared_error: 1.5439 - val_loss: 2.4781 - val_y1_output_loss: 0.5365 - val_y2_output_loss: 1.9417 - val_y1_output_root_mean_squared_error: 0.7324 - val_y2_output_root_mean_squared_error: 1.3934
# Epoch 116/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.2874 - y1_output_loss: 0.5654 - y2_output_loss: 1.7219 - y1_output_root_mean_squared_error: 0.7520 - y2_output_root_mean_squared_error: 1.3122 - val_loss: 2.6345 - val_y1_output_loss: 0.8499 - val_y2_output_loss: 1.7846 - val_y1_output_root_mean_squared_error: 0.9219 - val_y2_output_root_mean_squared_error: 1.3359
# Epoch 117/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.2959 - y1_output_loss: 0.5951 - y2_output_loss: 1.7007 - y1_output_root_mean_squared_error: 0.7714 - y2_output_root_mean_squared_error: 1.3041 - val_loss: 2.7067 - val_y1_output_loss: 0.7112 - val_y2_output_loss: 1.9955 - val_y1_output_root_mean_squared_error: 0.8433 - val_y2_output_root_mean_squared_error: 1.4126
# Epoch 118/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.3053 - y1_output_loss: 0.5094 - y2_output_loss: 1.7960 - y1_output_root_mean_squared_error: 0.7137 - y2_output_root_mean_squared_error: 1.3401 - val_loss: 3.5801 - val_y1_output_loss: 0.5468 - val_y2_output_loss: 3.0333 - val_y1_output_root_mean_squared_error: 0.7394 - val_y2_output_root_mean_squared_error: 1.7416
# Epoch 119/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.8048 - y1_output_loss: 1.0453 - y2_output_loss: 2.7596 - y1_output_root_mean_squared_error: 1.0224 - y2_output_root_mean_squared_error: 1.6612 - val_loss: 9.0988 - val_y1_output_loss: 1.8186 - val_y2_output_loss: 7.2802 - val_y1_output_root_mean_squared_error: 1.3486 - val_y2_output_root_mean_squared_error: 2.6982
# Epoch 120/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.0089 - y1_output_loss: 0.4859 - y2_output_loss: 1.5230 - y1_output_root_mean_squared_error: 0.6970 - y2_output_root_mean_squared_error: 1.2341 - val_loss: 5.5908 - val_y1_output_loss: 0.8884 - val_y2_output_loss: 4.7024 - val_y1_output_root_mean_squared_error: 0.9426 - val_y2_output_root_mean_squared_error: 2.1685
# Epoch 121/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.4501 - y1_output_loss: 0.5464 - y2_output_loss: 1.9037 - y1_output_root_mean_squared_error: 0.7392 - y2_output_root_mean_squared_error: 1.3797 - val_loss: 2.9524 - val_y1_output_loss: 0.6222 - val_y2_output_loss: 2.3302 - val_y1_output_root_mean_squared_error: 0.7888 - val_y2_output_root_mean_squared_error: 1.5265
# Epoch 122/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.1802 - y1_output_loss: 0.5031 - y2_output_loss: 1.6771 - y1_output_root_mean_squared_error: 0.7093 - y2_output_root_mean_squared_error: 1.2950 - val_loss: 6.9178 - val_y1_output_loss: 1.6157 - val_y2_output_loss: 5.3022 - val_y1_output_root_mean_squared_error: 1.2711 - val_y2_output_root_mean_squared_error: 2.3026
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5870 - y1_output_loss: 0.1449 - y2_output_loss: 0.4420 - y1_output_root_mean_squared_error: 0.3807 - y2_output_root_mean_squared_error: 0.6649 - val_loss: 1.0379 - val_y1_output_loss: 0.4074 - val_y2_output_loss: 0.6305 - val_y1_output_root_mean_squared_error: 0.6383 - val_y2_output_root_mean_squared_error: 0.7940
# Epoch 462/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4366 - y1_output_loss: 0.1274 - y2_output_loss: 0.3092 - y1_output_root_mean_squared_error: 0.3570 - y2_output_root_mean_squared_error: 0.5561 - val_loss: 1.0044 - val_y1_output_loss: 0.3427 - val_y2_output_loss: 0.6617 - val_y1_output_root_mean_squared_error: 0.5854 - val_y2_output_root_mean_squared_error: 0.8134
# Epoch 463/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.5338 - y1_output_loss: 0.5201 - y2_output_loss: 1.0137 - y1_output_root_mean_squared_error: 0.7212 - y2_output_root_mean_squared_error: 1.0068 - val_loss: 1.0878 - val_y1_output_loss: 0.2833 - val_y2_output_loss: 0.8045 - val_y1_output_root_mean_squared_error: 0.5322 - val_y2_output_root_mean_squared_error: 0.8970
# Epoch 464/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4502 - y1_output_loss: 0.1389 - y2_output_loss: 0.3113 - y1_output_root_mean_squared_error: 0.3727 - y2_output_root_mean_squared_error: 0.5579 - val_loss: 1.0797 - val_y1_output_loss: 0.3298 - val_y2_output_loss: 0.7499 - val_y1_output_root_mean_squared_error: 0.5743 - val_y2_output_root_mean_squared_error: 0.8660
# Epoch 465/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4487 - y1_output_loss: 0.1340 - y2_output_loss: 0.3147 - y1_output_root_mean_squared_error: 0.3660 - y2_output_root_mean_squared_error: 0.5610 - val_loss: 5.6710 - val_y1_output_loss: 0.5883 - val_y2_output_loss: 5.0827 - val_y1_output_root_mean_squared_error: 0.7670 - val_y2_output_root_mean_squared_error: 2.2545
# Epoch 466/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8138 - y1_output_loss: 0.1374 - y2_output_loss: 0.6763 - y1_output_root_mean_squared_error: 0.3707 - y2_output_root_mean_squared_error: 0.8224 - val_loss: 0.9721 - val_y1_output_loss: 0.3072 - val_y2_output_loss: 0.6649 - val_y1_output_root_mean_squared_error: 0.5542 - val_y2_output_root_mean_squared_error: 0.8154
# Epoch 467/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3686 - y1_output_loss: 0.1225 - y2_output_loss: 0.2461 - y1_output_root_mean_squared_error: 0.3500 - y2_output_root_mean_squared_error: 0.4961 - val_loss: 1.0410 - val_y1_output_loss: 0.2766 - val_y2_output_loss: 0.7644 - val_y1_output_root_mean_squared_error: 0.5260 - val_y2_output_root_mean_squared_error: 0.8743
# Epoch 468/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.7170 - y1_output_loss: 0.1928 - y2_output_loss: 0.5243 - y1_output_root_mean_squared_error: 0.4390 - y2_output_root_mean_squared_error: 0.7241 - val_loss: 1.0888 - val_y1_output_loss: 0.3094 - val_y2_output_loss: 0.7794 - val_y1_output_root_mean_squared_error: 0.5563 - val_y2_output_root_mean_squared_error: 0.8828
# Epoch 469/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5177 - y1_output_loss: 0.1349 - y2_output_loss: 0.3828 - y1_output_root_mean_squared_error: 0.3672 - y2_output_root_mean_squared_error: 0.6187 - val_loss: 1.5936 - val_y1_output_loss: 0.2577 - val_y2_output_loss: 1.3360 - val_y1_output_root_mean_squared_error: 0.5076 - val_y2_output_root_mean_squared_error: 1.1558
# Epoch 470/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3618 - y1_output_loss: 0.1119 - y2_output_loss: 0.2499 - y1_output_root_mean_squared_error: 0.3345 - y2_output_root_mean_squared_error: 0.4999 - val_loss: 0.9400 - val_y1_output_loss: 0.3004 - val_y2_output_loss: 0.6395 - val_y1_output_root_mean_squared_error: 0.5481 - val_y2_output_root_mean_squared_error: 0.7997
# Epoch 471/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4181 - y1_output_loss: 0.1329 - y2_output_loss: 0.2853 - y1_output_root_mean_squared_error: 0.3645 - y2_output_root_mean_squared_error: 0.5341 - val_loss: 0.9904 - val_y1_output_loss: 0.3130 - val_y2_output_loss: 0.6774 - val_y1_output_root_mean_squared_error: 0.5595 - val_y2_output_root_mean_squared_error: 0.8230
# Epoch 472/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4105 - y1_output_loss: 0.1380 - y2_output_loss: 0.2725 - y1_output_root_mean_squared_error: 0.3714 - y2_output_root_mean_squared_error: 0.5220 - val_loss: 1.0042 - val_y1_output_loss: 0.2730 - val_y2_output_loss: 0.7312 - val_y1_output_root_mean_squared_error: 0.5225 - val_y2_output_root_mean_squared_error: 0.8551
# Epoch 473/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5325 - y1_output_loss: 0.1401 - y2_output_loss: 0.3924 - y1_output_root_mean_squared_error: 0.3743 - y2_output_root_mean_squared_error: 0.6264 - val_loss: 0.9084 - val_y1_output_loss: 0.2918 - val_y2_output_loss: 0.6166 - val_y1_output_root_mean_squared_error: 0.5402 - val_y2_output_root_mean_squared_error: 0.7852
# Epoch 474/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5380 - y1_output_loss: 0.1602 - y2_output_loss: 0.3778 - y1_output_root_mean_squared_error: 0.4002 - y2_output_root_mean_squared_error: 0.6147 - val_loss: 1.0836 - val_y1_output_loss: 0.2829 - val_y2_output_loss: 0.8007 - val_y1_output_root_mean_squared_error: 0.5319 - val_y2_output_root_mean_squared_error: 0.8948
# Epoch 475/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4424 - y1_output_loss: 0.1335 - y2_output_loss: 0.3089 - y1_output_root_mean_squared_error: 0.3654 - y2_output_root_mean_squared_error: 0.5558 - val_loss: 0.9628 - val_y1_output_loss: 0.2691 - val_y2_output_loss: 0.6937 - val_y1_output_root_mean_squared_error: 0.5187 - val_y2_output_root_mean_squared_error: 0.8329
# Epoch 476/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4310 - y1_output_loss: 0.1253 - y2_output_loss: 0.3057 - y1_output_root_mean_squared_error: 0.3540 - y2_output_root_mean_squared_error: 0.5529 - val_loss: 2.2615 - val_y1_output_loss: 0.4876 - val_y2_output_loss: 1.7739 - val_y1_output_root_mean_squared_error: 0.6983 - val_y2_output_root_mean_squared_error: 1.3319
# Epoch 477/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4357 - y1_output_loss: 0.1209 - y2_output_loss: 0.3148 - y1_output_root_mean_squared_error: 0.3476 - y2_output_root_mean_squared_error: 0.5611 - val_loss: 1.1456 - val_y1_output_loss: 0.2913 - val_y2_output_loss: 0.8543 - val_y1_output_root_mean_squared_error: 0.5397 - val_y2_output_root_mean_squared_error: 0.9243
# Epoch 478/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3822 - y1_output_loss: 0.1289 - y2_output_loss: 0.2533 - y1_output_root_mean_squared_error: 0.3590 - y2_output_root_mean_squared_error: 0.5033 - val_loss: 0.9095 - val_y1_output_loss: 0.2902 - val_y2_output_loss: 0.6192 - val_y1_output_root_mean_squared_error: 0.5387 - val_y2_output_root_mean_squared_error: 0.7869
# Epoch 479/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4010 - y1_output_loss: 0.1192 - y2_output_loss: 0.2819 - y1_output_root_mean_squared_error: 0.3452 - y2_output_root_mean_squared_error: 0.5309 - val_loss: 1.3184 - val_y1_output_loss: 0.3450 - val_y2_output_loss: 0.9734 - val_y1_output_root_mean_squared_error: 0.5874 - val_y2_output_root_mean_squared_error: 0.9866
# Epoch 480/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5308 - y1_output_loss: 0.1324 - y2_output_loss: 0.3984 - y1_output_root_mean_squared_error: 0.3639 - y2_output_root_mean_squared_error: 0.6312 - val_loss: 1.0624 - val_y1_output_loss: 0.3547 - val_y2_output_loss: 0.7077 - val_y1_output_root_mean_squared_error: 0.5956 - val_y2_output_root_mean_squared_error: 0.8413
# Epoch 481/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6902 - y1_output_loss: 0.1832 - y2_output_loss: 0.5071 - y1_output_root_mean_squared_error: 0.4280 - y2_output_root_mean_squared_error: 0.7121 - val_loss: 1.3365 - val_y1_output_loss: 0.4383 - val_y2_output_loss: 0.8982 - val_y1_output_root_mean_squared_error: 0.6620 - val_y2_output_root_mean_squared_error: 0.9477
# Epoch 482/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3950 - y1_output_loss: 0.1226 - y2_output_loss: 0.2724 - y1_output_root_mean_squared_error: 0.3501 - y2_output_root_mean_squared_error: 0.5220 - val_loss: 1.2939 - val_y1_output_loss: 0.4849 - val_y2_output_loss: 0.8090 - val_y1_output_root_mean_squared_error: 0.6963 - val_y2_output_root_mean_squared_error: 0.8994
# Epoch 483/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3105 - y1_output_loss: 0.1090 - y2_output_loss: 0.2016 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.4490 - val_loss: 0.9401 - val_y1_output_loss: 0.3109 - val_y2_output_loss: 0.6292 - val_y1_output_root_mean_squared_error: 0.5576 - val_y2_output_root_mean_squared_error: 0.7932
# Epoch 484/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4067 - y1_output_loss: 0.1212 - y2_output_loss: 0.2855 - y1_output_root_mean_squared_error: 0.3481 - y2_output_root_mean_squared_error: 0.5343 - val_loss: 0.9215 - val_y1_output_loss: 0.2776 - val_y2_output_loss: 0.6440 - val_y1_output_root_mean_squared_error: 0.5268 - val_y2_output_root_mean_squared_error: 0.8025
# Epoch 485/500
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4167 - y1_output_loss: 0.1227 - y2_output_loss: 0.2940 - y1_output_root_mean_squared_error: 0.3503 - y2_output_root_mean_squared_error: 0.5422 - val_loss: 0.9634 - val_y1_output_loss: 0.2771 - val_y2_output_loss: 0.6863 - val_y1_output_root_mean_squared_error: 0.5264 - val_y2_output_root_mean_squared_error: 0.8285
# Epoch 486/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4531 - y1_output_loss: 0.1159 - y2_output_loss: 0.3372 - y1_output_root_mean_squared_error: 0.3404 - y2_output_root_mean_squared_error: 0.5807 - val_loss: 1.5009 - val_y1_output_loss: 0.3766 - val_y2_output_loss: 1.1242 - val_y1_output_root_mean_squared_error: 0.6137 - val_y2_output_root_mean_squared_error: 1.0603
# Epoch 487/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3809 - y1_output_loss: 0.1236 - y2_output_loss: 0.2573 - y1_output_root_mean_squared_error: 0.3516 - y2_output_root_mean_squared_error: 0.5072 - val_loss: 3.0037 - val_y1_output_loss: 0.4910 - val_y2_output_loss: 2.5126 - val_y1_output_root_mean_squared_error: 0.7007 - val_y2_output_root_mean_squared_error: 1.5851
# Epoch 488/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5750 - y1_output_loss: 0.1510 - y2_output_loss: 0.4240 - y1_output_root_mean_squared_error: 0.3886 - y2_output_root_mean_squared_error: 0.6512 - val_loss: 1.1519 - val_y1_output_loss: 0.2697 - val_y2_output_loss: 0.8822 - val_y1_output_root_mean_squared_error: 0.5193 - val_y2_output_root_mean_squared_error: 0.9393
# Epoch 489/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5949 - y1_output_loss: 0.1772 - y2_output_loss: 0.4178 - y1_output_root_mean_squared_error: 0.4209 - y2_output_root_mean_squared_error: 0.6464 - val_loss: 1.8804 - val_y1_output_loss: 0.3142 - val_y2_output_loss: 1.5663 - val_y1_output_root_mean_squared_error: 0.5605 - val_y2_output_root_mean_squared_error: 1.2515
# Epoch 490/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3768 - y1_output_loss: 0.1095 - y2_output_loss: 0.2673 - y1_output_root_mean_squared_error: 0.3310 - y2_output_root_mean_squared_error: 0.5170 - val_loss: 1.0939 - val_y1_output_loss: 0.3069 - val_y2_output_loss: 0.7870 - val_y1_output_root_mean_squared_error: 0.5540 - val_y2_output_root_mean_squared_error: 0.8871
# Epoch 491/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4464 - y1_output_loss: 0.1473 - y2_output_loss: 0.2991 - y1_output_root_mean_squared_error: 0.3838 - y2_output_root_mean_squared_error: 0.5469 - val_loss: 1.2558 - val_y1_output_loss: 0.3032 - val_y2_output_loss: 0.9526 - val_y1_output_root_mean_squared_error: 0.5507 - val_y2_output_root_mean_squared_error: 0.9760
# Epoch 492/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4557 - y1_output_loss: 0.1222 - y2_output_loss: 0.3336 - y1_output_root_mean_squared_error: 0.3495 - y2_output_root_mean_squared_error: 0.5775 - val_loss: 1.1997 - val_y1_output_loss: 0.2764 - val_y2_output_loss: 0.9233 - val_y1_output_root_mean_squared_error: 0.5258 - val_y2_output_root_mean_squared_error: 0.9609
# Epoch 493/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4122 - y1_output_loss: 0.1210 - y2_output_loss: 0.2913 - y1_output_root_mean_squared_error: 0.3478 - y2_output_root_mean_squared_error: 0.5397 - val_loss: 2.8280 - val_y1_output_loss: 0.3731 - val_y2_output_loss: 2.4549 - val_y1_output_root_mean_squared_error: 0.6108 - val_y2_output_root_mean_squared_error: 1.5668
# Epoch 494/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6092 - y1_output_loss: 0.1574 - y2_output_loss: 0.4518 - y1_output_root_mean_squared_error: 0.3968 - y2_output_root_mean_squared_error: 0.6721 - val_loss: 1.4135 - val_y1_output_loss: 0.4001 - val_y2_output_loss: 1.0133 - val_y1_output_root_mean_squared_error: 0.6326 - val_y2_output_root_mean_squared_error: 1.0066
# Epoch 495/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4979 - y1_output_loss: 0.1412 - y2_output_loss: 0.3567 - y1_output_root_mean_squared_error: 0.3757 - y2_output_root_mean_squared_error: 0.5972 - val_loss: 4.1923 - val_y1_output_loss: 0.9175 - val_y2_output_loss: 3.2748 - val_y1_output_root_mean_squared_error: 0.9579 - val_y2_output_root_mean_squared_error: 1.8096
# Epoch 496/500
# 62/62 [==============================] - 0s 7ms/step - loss: 0.5594 - y1_output_loss: 0.1454 - y2_output_loss: 0.4140 - y1_output_root_mean_squared_error: 0.3813 - y2_output_root_mean_squared_error: 0.6434 - val_loss: 1.5244 - val_y1_output_loss: 0.4667 - val_y2_output_loss: 1.0578 - val_y1_output_root_mean_squared_error: 0.6831 - val_y2_output_root_mean_squared_error: 1.0285
# Epoch 497/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3863 - y1_output_loss: 0.1213 - y2_output_loss: 0.2650 - y1_output_root_mean_squared_error: 0.3483 - y2_output_root_mean_squared_error: 0.5148 - val_loss: 0.9591 - val_y1_output_loss: 0.3325 - val_y2_output_loss: 0.6266 - val_y1_output_root_mean_squared_error: 0.5766 - val_y2_output_root_mean_squared_error: 0.7916
# Epoch 498/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4003 - y1_output_loss: 0.1217 - y2_output_loss: 0.2786 - y1_output_root_mean_squared_error: 0.3489 - y2_output_root_mean_squared_error: 0.5278 - val_loss: 0.9242 - val_y1_output_loss: 0.2786 - val_y2_output_loss: 0.6456 - val_y1_output_root_mean_squared_error: 0.5278 - val_y2_output_root_mean_squared_error: 0.8035
# Epoch 499/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5034 - y1_output_loss: 0.1299 - y2_output_loss: 0.3735 - y1_output_root_mean_squared_error: 0.3604 - y2_output_root_mean_squared_error: 0.6111 - val_loss: 0.9958 - val_y1_output_loss: 0.3296 - val_y2_output_loss: 0.6662 - val_y1_output_root_mean_squared_error: 0.5741 - val_y2_output_root_mean_squared_error: 0.8162
# Epoch 500/500
# 62/62 [==============================] - 1s 9ms/step - loss: 0.4469 - y1_output_loss: 0.1445 - y2_output_loss: 0.3024 - y1_output_root_mean_squared_error: 0.3802 - y2_output_root_mean_squared_error: 0.5499 - val_loss: 1.0702 - val_y1_output_loss: 0.2767 - val_y2_output_loss: 0.7935 - val_y1_output_root_mean_squared_error: 0.5260 - val_y2_output_root_mean_squared_error: 0.8908

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0702 - y1_output_loss: 0.2767 - y2_output_loss: 0.7935 - y1_output_root_mean_squared_error: 0.5260 - y2_output_root_mean_squared_error: 0.8908
# Loss = 1.0702168941497803, Y1_loss = 0.2766752243041992, Y1_mse = 0.5259992480278015, Y2_loss = 0.7935417294502258, Y2_mse = 0.8908095955848694

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
